# %%
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms

# %%
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)

# %%
#The compose function allows for multiple transforms
#transforms.ToTensor() converts our PILImage to a tensor of shape (C x H x W) in the range [0,1]
#transforms.Normalize(mean,std) normalizes a tensor to a (mean, std) for (R, G, B)
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_set = torchvision.datasets.CIFAR10(root='./cifardata', train=True, download=True, transform=transform)

test_set = torchvision.datasets.CIFAR10(root='./cifardata', train=False, download=True, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
from torch.utils.data.sampler import SubsetRandomSampler

#Training
n_training_samples = 20000
train_sampler = SubsetRandomSampler(np.arange(n_training_samples, dtype=np.int64))

#Validation
n_val_samples = 5000
val_sampler = SubsetRandomSampler(np.arange(n_training_samples, n_training_samples + n_val_samples, dtype=np.int64))

#Test
n_test_samples = 5000
test_sampler = SubsetRandomSampler(np.arange(n_test_samples, dtype=np.int64))

# %%
from torch.autograd import Variable
import torch.nn.functional as F

class CNN1(torch.nn.Module):
    
    #Our batch shape for input x is (3, 32, 32)
    
    def __init__(self):
        super(CNN1, self).__init__()
        #Input channels = 3, output channels = 18
        self.conv1 = torch.nn.Conv2d(3, 18, kernel_size=3, stride=1, padding=1)
        self.pool = torch.nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        
        #4608 input features, 64 output features (see sizing flow below)
        self.fc1 = torch.nn.Linear(18 * 16 * 16, 64)
        
        #64 input features, 10 output features for our 10 defined classes
        self.fc2 = torch.nn.Linear(64, 10)
        
    def forward(self, x):
        
        #Computes the activation of the first convolution
        #Size changes from (3, 32, 32) to (18, 32, 32)
        x = F.relu(self.conv1(x))
        
        #Size changes from (18, 32, 32) to (18, 16, 16)
        x = self.pool(x)
        
        #Reshape data to input to the input layer of the neural net
        #Size changes from (18, 16, 16) to (1, 4608)
        #Recall that the -1 infers this dimension from the other given dimension
        x = x.view(-1, 18 * 16 *16)
        
        #Computes the activation of the first fully connected layer
        #Size changes from (1, 4608) to (1, 64)
        x = F.relu(self.fc1(x))
        
        #Computes the second fully connected layer (activation applied later)
        #Size changes from (1, 64) to (1, 10)
        x = self.fc2(x)
        return(x)

# %%
def outputSize(in_size, kernel_size, stride, padding):

    output = int((in_size - kernel_size + 2*(padding)) / stride) + 1

    return(output)

# %%
def get_train_loader(batch_size):
    train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size,
                                           sampler=train_sampler, num_workers=2)
    return(train_loader)

# %%
#Test and validation loaders have constant batch sizes, so we can define them directly
test_loader = torch.utils.data.DataLoader(test_set, batch_size=4, sampler=test_sampler, num_workers=2)
val_loader = torch.utils.data.DataLoader(train_set, batch_size=128, sampler=val_sampler, num_workers=2)

# %%
import torch.optim as optim

def createLossAndOptimizer(net, learning_rate=0.001):
    
    #Loss function
    loss = torch.nn.CrossEntropyLoss()
    
    #Optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    return(loss, optimizer)

# %%
import time

def trainNet(net, batch_size, n_epochs, learning_rate):
    
    #Print all of the hyperparameters of the training iteration:
    print("===== HYPERPARAMETERS =====")
    print("batch_size=", batch_size)
    print("epochs=", n_epochs)
    print("learning_rate=", learning_rate)
    print("=" * 30)
    
    #Get training data
    train_loader = get_train_loader(batch_size)
    n_batches = len(train_loader)
    
    #Create our loss and optimizer functions
    loss, optimizer = createLossAndOptimizer(net, learning_rate)
    
    #Time for printing
    training_start_time = time.time()
    
    #Loop for n_epochs
    for epoch in range(n_epochs):
        
        running_loss = 0.0
        print_every = n_batches // 10
        start_time = time.time()
        total_train_loss = 0
        
        for i, data in enumerate(train_loader, 0):
            
            #Get inputs
            inputs, labels = data
            
            #Wrap them in a Variable object
            inputs, labels = Variable(inputs), Variable(labels)
            
            #Set the parameter gradients to zero
            optimizer.zero_grad()
            
            #Forward pass, backward pass, optimize
            outputs = net(inputs)
            loss_size = loss(outputs, labels)
            loss_size.backward()
            optimizer.step()
            
            #Print statistics
            running_loss += loss_size.data[0]
            total_train_loss += loss_size.data[0]
            
            #Print every 10th batch of an epoch
            if (i + 1) % (print_every + 1) == 0:
                print("Epoch {}, {:d}% \t train_loss: {:.2f} took: {:.2f}s".format(
                        epoch+1, int(100 * (i+1) / n_batches), running_loss / print_every, time.time() - start_time))
                #Reset running loss and time
                running_loss = 0.0
                start_time = time.time()
            
        #At the end of the epoch, do a pass on the validation set
        total_val_loss = 0
        for inputs, labels in val_loader:
            
            #Wrap tensors in Variables
            inputs, labels = Variable(inputs), Variable(labels)
            
            #Forward pass
            val_outputs = net(inputs)
            val_loss_size = loss(val_outputs, labels)
            total_val_loss += val_loss_size.data[0]
            
        print("Validation loss = {:.2f}".format(total_val_loss / len(val_loader)))
        
    print("Training finished, took {:.2f}s".format(time.time() - training_start_time))

# %%
CNN = CNN1()
trainNet(CNN, batch_size=32, n_epochs=20, learning_rate=0.001)
# Out:
# ===== HYPERPARAMETERS =====
# batch_size= 32
# epochs= 20
# learning_rate= 0.001
# ==============================
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:48: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:49: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# Epoch 1, 10% 	 train_loss: 2.12 took: 1.36s
# Epoch 1, 20% 	 train_loss: 1.87 took: 1.23s
# Epoch 1, 30% 	 train_loss: 1.72 took: 1.24s
# Epoch 1, 40% 	 train_loss: 1.65 took: 1.26s
# Epoch 1, 50% 	 train_loss: 1.63 took: 1.26s
# Epoch 1, 60% 	 train_loss: 1.51 took: 1.27s
# Epoch 1, 70% 	 train_loss: 1.51 took: 1.24s
# Epoch 1, 80% 	 train_loss: 1.48 took: 1.28s
# Epoch 1, 90% 	 train_loss: 1.42 took: 1.31s
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:69: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# Validation loss = 1.36
# Epoch 2, 10% 	 train_loss: 1.35 took: 1.74s
# Epoch 2, 20% 	 train_loss: 1.33 took: 2.87s
# Epoch 2, 30% 	 train_loss: 1.33 took: 2.98s
# Epoch 2, 40% 	 train_loss: 1.33 took: 2.57s
# Epoch 2, 50% 	 train_loss: 1.29 took: 2.25s
# Epoch 2, 60% 	 train_loss: 1.32 took: 2.23s
# Epoch 2, 70% 	 train_loss: 1.29 took: 2.22s
# Epoch 2, 80% 	 train_loss: 1.27 took: 2.23s
# Epoch 2, 90% 	 train_loss: 1.29 took: 2.20s
# Validation loss = 1.24
# Epoch 3, 10% 	 train_loss: 1.19 took: 2.35s
# Epoch 3, 20% 	 train_loss: 1.17 took: 2.26s
# Epoch 3, 30% 	 train_loss: 1.22 took: 2.25s
# Epoch 3, 40% 	 train_loss: 1.18 took: 2.21s
# Epoch 3, 50% 	 train_loss: 1.20 took: 2.31s
# Epoch 3, 60% 	 train_loss: 1.20 took: 2.22s
# Epoch 3, 70% 	 train_loss: 1.22 took: 2.27s
# Epoch 3, 80% 	 train_loss: 1.16 took: 2.35s
# Epoch 3, 90% 	 train_loss: 1.17 took: 2.31s
# Validation loss = 1.21
# Epoch 4, 10% 	 train_loss: 1.06 took: 2.35s
# Epoch 4, 20% 	 train_loss: 1.09 took: 2.28s
# Epoch 4, 30% 	 train_loss: 1.09 took: 2.29s
# Epoch 4, 40% 	 train_loss: 1.11 took: 2.32s
# Epoch 4, 50% 	 train_loss: 1.10 took: 2.33s
# Epoch 4, 60% 	 train_loss: 1.07 took: 2.19s
# Epoch 4, 70% 	 train_loss: 1.09 took: 2.19s
# Epoch 4, 80% 	 train_loss: 1.07 took: 2.19s
# Epoch 4, 90% 	 train_loss: 1.12 took: 2.15s
# Validation loss = 1.18
# Epoch 5, 10% 	 train_loss: 1.00 took: 2.25s
# Epoch 5, 20% 	 train_loss: 1.01 took: 2.15s
# Epoch 5, 30% 	 train_loss: 1.01 took: 2.20s
# Epoch 5, 40% 	 train_loss: 1.04 took: 2.28s
# Epoch 5, 50% 	 train_loss: 1.01 took: 2.28s
# Epoch 5, 60% 	 train_loss: 1.01 took: 2.27s
# Epoch 5, 70% 	 train_loss: 1.02 took: 2.27s
# Epoch 5, 80% 	 train_loss: 1.01 took: 2.26s
# Epoch 5, 90% 	 train_loss: 1.04 took: 2.27s
# Validation loss = 1.16
# Epoch 6, 10% 	 train_loss: 0.90 took: 2.32s
# Epoch 6, 20% 	 train_loss: 0.89 took: 2.26s
# Epoch 6, 30% 	 train_loss: 0.90 took: 2.25s
# Epoch 6, 40% 	 train_loss: 0.96 took: 2.23s
# Epoch 6, 50% 	 train_loss: 0.92 took: 2.25s
# Epoch 6, 60% 	 train_loss: 0.94 took: 2.28s
# Epoch 6, 70% 	 train_loss: 0.95 took: 2.21s
# Epoch 6, 80% 	 train_loss: 1.01 took: 2.22s
# Epoch 6, 90% 	 train_loss: 0.98 took: 2.22s
# Validation loss = 1.16
# Epoch 7, 10% 	 train_loss: 0.83 took: 2.37s
# Epoch 7, 20% 	 train_loss: 0.88 took: 2.30s
# Epoch 7, 30% 	 train_loss: 0.84 took: 2.26s
# Epoch 7, 40% 	 train_loss: 0.87 took: 2.27s
# Epoch 7, 50% 	 train_loss: 0.88 took: 2.25s
# Epoch 7, 60% 	 train_loss: 0.85 took: 2.27s
# Epoch 7, 70% 	 train_loss: 0.91 took: 2.29s
# Epoch 7, 80% 	 train_loss: 0.91 took: 2.30s
# Epoch 7, 90% 	 train_loss: 0.91 took: 2.28s
# Validation loss = 1.18
# Epoch 8, 10% 	 train_loss: 0.76 took: 2.34s
# Epoch 8, 20% 	 train_loss: 0.79 took: 2.22s
# Epoch 8, 30% 	 train_loss: 0.77 took: 2.27s
# Epoch 8, 40% 	 train_loss: 0.78 took: 2.27s
# Epoch 8, 50% 	 train_loss: 0.88 took: 2.28s
# Epoch 8, 60% 	 train_loss: 0.82 took: 2.28s
# Epoch 8, 70% 	 train_loss: 0.85 took: 2.25s
# Epoch 8, 80% 	 train_loss: 0.83 took: 2.24s
# Epoch 8, 90% 	 train_loss: 0.83 took: 2.30s
# Validation loss = 1.20
# Epoch 9, 10% 	 train_loss: 0.70 took: 2.34s
# Epoch 9, 20% 	 train_loss: 0.80 took: 2.31s
# Epoch 9, 30% 	 train_loss: 0.76 took: 2.26s
# Epoch 9, 40% 	 train_loss: 0.76 took: 2.27s
# Epoch 9, 50% 	 train_loss: 0.73 took: 2.28s
# Epoch 9, 60% 	 train_loss: 0.73 took: 2.27s
# Epoch 9, 70% 	 train_loss: 0.75 took: 2.26s
# Epoch 9, 80% 	 train_loss: 0.77 took: 2.20s
# Epoch 9, 90% 	 train_loss: 0.78 took: 2.22s
# Validation loss = 1.26
# Epoch 10, 10% 	 train_loss: 0.66 took: 2.38s
# Epoch 10, 20% 	 train_loss: 0.68 took: 2.27s
# Epoch 10, 30% 	 train_loss: 0.71 took: 2.25s
# Epoch 10, 40% 	 train_loss: 0.73 took: 2.25s
# Epoch 10, 50% 	 train_loss: 0.70 took: 2.31s
# Epoch 10, 60% 	 train_loss: 0.70 took: 2.23s
# Epoch 10, 70% 	 train_loss: 0.74 took: 2.22s
# Epoch 10, 80% 	 train_loss: 0.73 took: 2.29s
# Epoch 10, 90% 	 train_loss: 0.77 took: 2.28s
# Validation loss = 1.24
# Epoch 11, 10% 	 train_loss: 0.60 took: 2.33s
# Epoch 11, 20% 	 train_loss: 0.61 took: 2.24s
# Epoch 11, 30% 	 train_loss: 0.62 took: 2.26s
# Epoch 11, 40% 	 train_loss: 0.63 took: 2.26s
# Epoch 11, 50% 	 train_loss: 0.68 took: 2.26s
# Epoch 11, 60% 	 train_loss: 0.70 took: 2.25s
# Epoch 11, 70% 	 train_loss: 0.68 took: 2.24s
# Epoch 11, 80% 	 train_loss: 0.74 took: 2.25s
# Epoch 11, 90% 	 train_loss: 0.69 took: 2.23s
# Validation loss = 1.29
# Epoch 12, 10% 	 train_loss: 0.55 took: 2.35s
# Epoch 12, 20% 	 train_loss: 0.57 took: 2.36s
# Epoch 12, 30% 	 train_loss: 0.64 took: 2.27s
# Epoch 12, 40% 	 train_loss: 0.57 took: 2.28s
# Epoch 12, 50% 	 train_loss: 0.60 took: 2.31s
# Epoch 12, 60% 	 train_loss: 0.63 took: 2.31s
# Epoch 12, 70% 	 train_loss: 0.64 took: 2.29s
# Epoch 12, 80% 	 train_loss: 0.62 took: 2.29s
# Epoch 12, 90% 	 train_loss: 0.66 took: 2.30s
# Validation loss = 1.32
# Epoch 13, 10% 	 train_loss: 0.51 took: 2.37s
# Epoch 13, 20% 	 train_loss: 0.51 took: 2.30s
# Epoch 13, 30% 	 train_loss: 0.56 took: 2.32s
# Epoch 13, 40% 	 train_loss: 0.54 took: 2.24s
# Epoch 13, 50% 	 train_loss: 0.55 took: 2.26s
# Epoch 13, 60% 	 train_loss: 0.59 took: 2.25s
# Epoch 13, 70% 	 train_loss: 0.61 took: 2.27s
# Epoch 13, 80% 	 train_loss: 0.58 took: 2.25s
# Epoch 13, 90% 	 train_loss: 0.61 took: 2.26s
# Validation loss = 1.32
# Epoch 14, 10% 	 train_loss: 0.46 took: 2.34s
# Epoch 14, 20% 	 train_loss: 0.48 took: 2.30s
# Epoch 14, 30% 	 train_loss: 0.50 took: 2.27s
# Epoch 14, 40% 	 train_loss: 0.55 took: 2.28s
# Epoch 14, 50% 	 train_loss: 0.51 took: 2.26s
# Epoch 14, 60% 	 train_loss: 0.48 took: 2.27s
# Epoch 14, 70% 	 train_loss: 0.55 took: 2.24s
# Epoch 14, 80% 	 train_loss: 0.56 took: 2.30s
# Epoch 14, 90% 	 train_loss: 0.55 took: 2.28s
# Validation loss = 1.41
# Epoch 15, 10% 	 train_loss: 0.42 took: 2.34s
# Epoch 15, 20% 	 train_loss: 0.44 took: 2.23s
# Epoch 15, 30% 	 train_loss: 0.46 took: 2.27s
# Epoch 15, 40% 	 train_loss: 0.47 took: 2.26s
# Epoch 15, 50% 	 train_loss: 0.49 took: 2.25s
# Epoch 15, 60% 	 train_loss: 0.48 took: 2.27s
# Epoch 15, 70% 	 train_loss: 0.50 took: 2.29s
# Epoch 15, 80% 	 train_loss: 0.54 took: 2.27s
# Epoch 15, 90% 	 train_loss: 0.52 took: 2.27s
# Validation loss = 1.43
# Epoch 16, 10% 	 train_loss: 0.42 took: 2.31s
# Epoch 16, 20% 	 train_loss: 0.40 took: 2.28s
# Epoch 16, 30% 	 train_loss: 0.41 took: 2.26s
# Epoch 16, 40% 	 train_loss: 0.43 took: 2.28s
# Epoch 16, 50% 	 train_loss: 0.43 took: 2.28s
# Epoch 16, 60% 	 train_loss: 0.51 took: 2.25s
# Epoch 16, 70% 	 train_loss: 0.44 took: 2.25s
# Epoch 16, 80% 	 train_loss: 0.46 took: 2.25s
# Epoch 16, 90% 	 train_loss: 0.46 took: 2.27s
# Validation loss = 1.54
# Epoch 17, 10% 	 train_loss: 0.36 took: 2.38s
# Epoch 17, 20% 	 train_loss: 0.38 took: 2.23s
# Epoch 17, 30% 	 train_loss: 0.37 took: 2.26s
# Epoch 17, 40% 	 train_loss: 0.40 took: 2.29s
# Epoch 17, 50% 	 train_loss: 0.42 took: 2.28s
# Epoch 17, 60% 	 train_loss: 0.41 took: 2.26s
# Epoch 17, 70% 	 train_loss: 0.40 took: 2.28s
# Epoch 17, 80% 	 train_loss: 0.43 took: 2.25s
# Epoch 17, 90% 	 train_loss: 0.43 took: 2.26s
# Validation loss = 1.57
# Epoch 18, 10% 	 train_loss: 0.34 took: 2.39s
# Epoch 18, 20% 	 train_loss: 0.32 took: 2.31s
# Epoch 18, 30% 	 train_loss: 0.39 took: 2.26s
# Epoch 18, 40% 	 train_loss: 0.37 took: 2.18s
# Epoch 18, 50% 	 train_loss: 0.38 took: 2.16s
# Epoch 18, 60% 	 train_loss: 0.43 took: 2.22s
# Epoch 18, 70% 	 train_loss: 0.41 took: 2.29s
# Epoch 18, 80% 	 train_loss: 0.39 took: 2.28s
# Epoch 18, 90% 	 train_loss: 0.38 took: 2.23s
# Validation loss = 1.65
# Epoch 19, 10% 	 train_loss: 0.30 took: 2.35s
# Epoch 19, 20% 	 train_loss: 0.33 took: 2.28s
# Epoch 19, 30% 	 train_loss: 0.30 took: 2.31s
# Epoch 19, 40% 	 train_loss: 0.30 took: 2.30s
# Epoch 19, 50% 	 train_loss: 0.34 took: 2.26s
# Epoch 19, 60% 	 train_loss: 0.36 took: 2.29s
# Epoch 19, 70% 	 train_loss: 0.36 took: 2.30s
# Epoch 19, 80% 	 train_loss: 0.36 took: 2.28s
# Epoch 19, 90% 	 train_loss: 0.38 took: 2.26s
# Validation loss = 1.71
# Epoch 20, 10% 	 train_loss: 0.28 took: 2.40s
# Epoch 20, 20% 	 train_loss: 0.28 took: 2.27s
# Epoch 20, 30% 	 train_loss: 0.30 took: 2.24s
# Epoch 20, 40% 	 train_loss: 0.29 took: 2.29s
# Epoch 20, 50% 	 train_loss: 0.31 took: 2.25s
# Epoch 20, 60% 	 train_loss: 0.31 took: 2.28s
# Epoch 20, 70% 	 train_loss: 0.32 took: 2.31s
# Epoch 20, 80% 	 train_loss: 0.33 took: 2.28s
# Epoch 20, 90% 	 train_loss: 0.34 took: 2.28s
# Validation loss = 1.78
# Training finished, took 456.72s

# %% [markdown]
# # Exercise 1:
# # Modify the function "trainNet" so that it will also generate a plot for training loss and validation loss for each epoch.

# %% [markdown]
# # Exercise 2:
# # Create a new "CNN2" class with network described as :
# # Input, conv 3x3 10 kernels 'same' padding, ReLu, Draopout 0.1, pool max 2x2, conv 3x3 20 kernels 'same' padding, ReLu, Dropout 0.2, pool max 2x2, flatten, FC/Dense 200, FC/Dense 100, Softmax 10.
# # Train this class using the "trainNet" function and same dataset.

# %%
class CNN2(torch.nn.Module):
    
    #Our batch shape for input x is (3, 32, 32)
    
    def __init__(self):
        super(CNN2, self).__init__()
        
    def forward(self, x):
        
        pass
